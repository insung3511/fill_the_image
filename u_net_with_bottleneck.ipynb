# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model
from tensorflow.keras import layers
from tensorflow import keras

from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm

import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import visualkeras
import cv2
import os

np.random.seed(42)

# %% [markdown]
# # Data Load & Data Pre-processing

# %%
X_DATA_PATH = "./data/cropped/"
Y_DATA_PATH = "./data/resized/"

x_data_path_list = os.listdir(X_DATA_PATH)
y_data_path_list = os.listdir(Y_DATA_PATH)

X, y = list(), list()
for x_data_path in tqdm(x_data_path_list, desc=f'X data loading...'):   X.append(cv2.imread(X_DATA_PATH + x_data_path))
for y_data_path in tqdm(y_data_path_list, desc=f'Y data loading...'):   y.append(cv2.imread(Y_DATA_PATH + y_data_path))
# Out:
# X data loading...: 100%|██████████| 1000/1000 [00:00<00:00, 2824.55it/s]
# Y data loading...: 100%|██████████| 1000/1000 [00:00<00:00, 2684.02it/s]

# %%
X = np.array(X)
y = np.array(y)

plt.title("Original Image Boxplot")
plt.boxplot(X.reshape(-1, 3))
plt.boxplot(y.reshape(-1, 3))
plt.show()

# Pre-processing
X = X.astype('float32') / 255.
y = y.astype('float32') / 255.

plt.title("Normalized Image Boxplot")
plt.boxplot(X.reshape(-1, 3))
plt.boxplot(y.reshape(-1, 3))
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(f"""X_train shape: {X_train.shape}
y_train shape: {y_train.shape}
X_test shape: {X_test.shape}
y_test shape: {y_test.shape}""")
# Out:
# X_train shape: (700, 256, 256, 3)
# y_train shape: (700, 256, 256, 3)
# X_test shape: (300, 256, 256, 3)
# y_test shape: (300, 256, 256, 3)

# %%
randlist = np.random.randint(0, X_train.shape[0], 10)

ax, fig = plt.subplots(10, 2, figsize=(10, 30))
for i, j in zip(range(10), randlist):
    fig[i][0].title.set_text(f"X_train[{j}]")
    fig[i][1].title.set_text(f"y_train[{j}]")
    fig[i][0].imshow(X_train[j])
    fig[i][1].imshow(y_train[j])
plt.show()

# %% [markdown]
# # Modeling

# %%
outDir = './checkpoint_unet/' # 이 경로에 best 모델이 저장된다.
model_names = outDir + 'weights-{epoch}-{val_loss:.8f}.h5'
def get_callbacks(patience = 50):
    model_checkpoint = ModelCheckpoint(model_names, monitor='val_loss', save_best_only=True, period = 1)
    callbacks = [model_checkpoint]
    return callbacks

callback = get_callbacks()
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# ResNet BottleNeck Block
def BottleNeck(input_feature, in_channels, out_channels):
    x1 = Conv2D(in_channels, (1, 1), padding='same', activation='relu')(input_feature)
    x1 = layers.BatchNormalization()(x1)
    skip_connection = x1

    x1 = Conv2D(in_channels, (3, 3), padding='same', activation='relu')(x1)
    x1 = layers.BatchNormalization()(x1)

    x1 = Conv2D(out_channels, (1, 1), padding='same', activation='relu')(x1)
    x1 = layers.BatchNormalization()(x1)

    x1 = layers.add([x1, skip_connection])
    x1 = layers.Activation('relu')(x1)

    return x1

# Import U-Net
def unet(input_size=(256, 256, 3)):
    inputs = Input(input_size)

    x1 = BottleNeck(inputs, 64, 64)
    x1 = BottleNeck(x1, 64, 64)

    x2 = MaxPooling2D((2, 2))(x1)
    x2 = BottleNeck(x2, 128, 128)
    x2 = BottleNeck(x2, 128, 128)

    x3 = MaxPooling2D((2, 2))(x2)
    x3 = BottleNeck(x3, 256, 256)
    x3 = BottleNeck(x3, 256, 256)

    x4 = MaxPooling2D((2, 2))(x3)
    x4 = BottleNeck(x4, 512, 512)
    x4 = BottleNeck(x4, 512, 512)

    up1 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(x4), x3], axis=-1)
    up1 = BottleNeck(up1, 256, 256)
    up1 = BottleNeck(up1, 256, 256)

    up2 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(up1), x2], axis=-1)
    up2 = BottleNeck(up2, 128, 128)
    up2 = BottleNeck(up2, 128, 128)

    up3 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(up2), x1], axis=-1)
    up3 = BottleNeck(up3, 64, 64)
    up3 = BottleNeck(up3, 64, 64)

    classify = Conv2D(3, (1, 1), activation='sigmoid')(up3)

    # conv1 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(inputs)
    # conv1 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv1)
    # pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    # conv2 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool1)
    # conv2 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv2)
    # pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    # conv3 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool2)
    # conv3 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv3)
    # pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    # conv4 = Conv2D(512, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool3)
    # conv4 = Conv2D(512, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv4)
    # drop4 = layers.Dropout(0.5)(conv4)
    # pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    # conv5 = Conv2D(1024, 3, activation='relu', padding='same', kernel_initializer='he_normal')(pool4)
    # conv5 = Conv2D(1024, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv5)
    # drop5 = layers.Dropout(0.5)(conv5)

    # up6 = Conv2D(512, 2, activation='relu', padding='same', kernel_initializer='he_normal')(layers.UpSampling2D(size=(2, 2))(drop5))
    # merge6 = concatenate([drop4, up6], axis=3)
    # conv6 = Conv2D(512, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge6)
    # conv6 = Conv2D(512, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv6)

    # up7 = Conv2D(256, 2, activation='relu', padding='same', kernel_initializer='he_normal')(layers.UpSampling2D(size=(2, 2))(conv6))
    # merge7 = concatenate([conv3, up7], axis=3)
    # conv7 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge7)
    # conv7 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv7)

    # up8 = Conv2D(128, 2, activation='relu', padding='same', kernel_initializer='he_normal')(layers.UpSampling2D(size=(2, 2))(conv7))
    # merge8 = concatenate([conv2, up8], axis=3)
    # conv8 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge8)
    # conv8 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv8)

    # up9 = Conv2D(64, 2, activation='relu', padding='same', kernel_initializer='he_normal')(layers.UpSampling2D(size=(2, 2))(conv8))
    # merge9 = concatenate([conv1, up9], axis=3)
    # conv9 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(merge9)
    # conv9 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer='he_normal')(conv9)

    # conv10 = Conv2D(3, 1, activation='sigmoid')(conv9)

    # model = Model(inputs=inputs, outputs=conv10)

    model = Model(inputs=inputs, outputs=classify)

    return model

# %%
model = unet(input_size=(256, 256, 3))
optimizer_f = keras.optimizers.Adam(learning_rate=0.0001)
loss_f = keras.losses.MeanSquaredError()

model.compile(optimizer=optimizer_f, loss=loss_f, metrics=['accuracy'])
model.summary()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_6 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_215 (Conv2D)         (None, 256, 256, 64)         256       ['input_6[0][0]']
#
#  batch_normalization_210 (B  (None, 256, 256, 64)         256       ['conv2d_215[0][0]']
#  atchNormalization)
#
#  conv2d_216 (Conv2D)         (None, 256, 256, 64)         36928     ['batch_normalization_210[0][0
#                                                                     ]']
#
#  batch_normalization_211 (B  (None, 256, 256, 64)         256       ['conv2d_216[0][0]']
#  atchNormalization)
#
#  conv2d_217 (Conv2D)         (None, 256, 256, 64)         4160      ['batch_normalization_211[0][0
#                                                                     ]']
#
#  batch_normalization_212 (B  (None, 256, 256, 64)         256       ['conv2d_217[0][0]']
#  atchNormalization)
#
#  add_70 (Add)                (None, 256, 256, 64)         0         ['batch_normalization_212[0][0
#                                                                     ]',
#                                                                      'batch_normalization_210[0][0
#                                                                     ]']
#
#  activation_70 (Activation)  (None, 256, 256, 64)         0         ['add_70[0][0]']
#
#  conv2d_218 (Conv2D)         (None, 256, 256, 64)         4160      ['activation_70[0][0]']
#
#  batch_normalization_213 (B  (None, 256, 256, 64)         256       ['conv2d_218[0][0]']
#  atchNormalization)
#
#  conv2d_219 (Conv2D)         (None, 256, 256, 64)         36928     ['batch_normalization_213[0][0
#                                                                     ]']
#
#  batch_normalization_214 (B  (None, 256, 256, 64)         256       ['conv2d_219[0][0]']
#  atchNormalization)
#
#  conv2d_220 (Conv2D)         (None, 256, 256, 64)         4160      ['batch_normalization_214[0][0
#                                                                     ]']
#
#  batch_normalization_215 (B  (None, 256, 256, 64)         256       ['conv2d_220[0][0]']
#  atchNormalization)
#
#  add_71 (Add)                (None, 256, 256, 64)         0         ['batch_normalization_215[0][0
#                                                                     ]',
#                                                                      'batch_normalization_213[0][0
#                                                                     ]']
#
#  activation_71 (Activation)  (None, 256, 256, 64)         0         ['add_71[0][0]']
#
#  max_pooling2d_15 (MaxPooli  (None, 128, 128, 64)         0         ['activation_71[0][0]']
#  ng2D)
#
#  conv2d_221 (Conv2D)         (None, 128, 128, 128)        8320      ['max_pooling2d_15[0][0]']
#
#  batch_normalization_216 (B  (None, 128, 128, 128)        512       ['conv2d_221[0][0]']
#  atchNormalization)
#
#  conv2d_222 (Conv2D)         (None, 128, 128, 128)        147584    ['batch_normalization_216[0][0
#                                                                     ]']
#
#  batch_normalization_217 (B  (None, 128, 128, 128)        512       ['conv2d_222[0][0]']
#  atchNormalization)
#
#  conv2d_223 (Conv2D)         (None, 128, 128, 128)        16512     ['batch_normalization_217[0][0
#                                                                     ]']
#
#  batch_normalization_218 (B  (None, 128, 128, 128)        512       ['conv2d_223[0][0]']
#  atchNormalization)
#
#  add_72 (Add)                (None, 128, 128, 128)        0         ['batch_normalization_218[0][0
#                                                                     ]',
#                                                                      'batch_normalization_216[0][0
#                                                                     ]']
#
#  activation_72 (Activation)  (None, 128, 128, 128)        0         ['add_72[0][0]']
#
#  conv2d_224 (Conv2D)         (None, 128, 128, 128)        16512     ['activation_72[0][0]']
#
#  batch_normalization_219 (B  (None, 128, 128, 128)        512       ['conv2d_224[0][0]']
#  atchNormalization)
#
#  conv2d_225 (Conv2D)         (None, 128, 128, 128)        147584    ['batch_normalization_219[0][0
#                                                                     ]']
#
#  batch_normalization_220 (B  (None, 128, 128, 128)        512       ['conv2d_225[0][0]']
#  atchNormalization)
#
#  conv2d_226 (Conv2D)         (None, 128, 128, 128)        16512     ['batch_normalization_220[0][0
#                                                                     ]']
#
#  batch_normalization_221 (B  (None, 128, 128, 128)        512       ['conv2d_226[0][0]']
#  atchNormalization)
#
#  add_73 (Add)                (None, 128, 128, 128)        0         ['batch_normalization_221[0][0
#                                                                     ]',
#                                                                      'batch_normalization_219[0][0
#                                                                     ]']
#
#  activation_73 (Activation)  (None, 128, 128, 128)        0         ['add_73[0][0]']
#
#  max_pooling2d_16 (MaxPooli  (None, 64, 64, 128)          0         ['activation_73[0][0]']
#  ng2D)
#
#  conv2d_227 (Conv2D)         (None, 64, 64, 256)          33024     ['max_pooling2d_16[0][0]']
#
#  batch_normalization_222 (B  (None, 64, 64, 256)          1024      ['conv2d_227[0][0]']
#  atchNormalization)
#
#  conv2d_228 (Conv2D)         (None, 64, 64, 256)          590080    ['batch_normalization_222[0][0
#                                                                     ]']
#
#  batch_normalization_223 (B  (None, 64, 64, 256)          1024      ['conv2d_228[0][0]']
#  atchNormalization)
#
#  conv2d_229 (Conv2D)         (None, 64, 64, 256)          65792     ['batch_normalization_223[0][0
#                                                                     ]']
#
#  batch_normalization_224 (B  (None, 64, 64, 256)          1024      ['conv2d_229[0][0]']
#  atchNormalization)
#
#  add_74 (Add)                (None, 64, 64, 256)          0         ['batch_normalization_224[0][0
#                                                                     ]',
#                                                                      'batch_normalization_222[0][0
#                                                                     ]']
#
#  activation_74 (Activation)  (None, 64, 64, 256)          0         ['add_74[0][0]']
#
#  conv2d_230 (Conv2D)         (None, 64, 64, 256)          65792     ['activation_74[0][0]']
#
#  batch_normalization_225 (B  (None, 64, 64, 256)          1024      ['conv2d_230[0][0]']
#  atchNormalization)
#
#  conv2d_231 (Conv2D)         (None, 64, 64, 256)          590080    ['batch_normalization_225[0][0
#                                                                     ]']
#
#  batch_normalization_226 (B  (None, 64, 64, 256)          1024      ['conv2d_231[0][0]']
#  atchNormalization)
#
#  conv2d_232 (Conv2D)         (None, 64, 64, 256)          65792     ['batch_normalization_226[0][0
#                                                                     ]']
#
#  batch_normalization_227 (B  (None, 64, 64, 256)          1024      ['conv2d_232[0][0]']
#  atchNormalization)
#
#  add_75 (Add)                (None, 64, 64, 256)          0         ['batch_normalization_227[0][0
#                                                                     ]',
#                                                                      'batch_normalization_225[0][0
#                                                                     ]']
#
#  activation_75 (Activation)  (None, 64, 64, 256)          0         ['add_75[0][0]']
#
#  max_pooling2d_17 (MaxPooli  (None, 32, 32, 256)          0         ['activation_75[0][0]']
#  ng2D)
#
#  conv2d_233 (Conv2D)         (None, 32, 32, 512)          131584    ['max_pooling2d_17[0][0]']
#
#  batch_normalization_228 (B  (None, 32, 32, 512)          2048      ['conv2d_233[0][0]']
#  atchNormalization)
#
#  conv2d_234 (Conv2D)         (None, 32, 32, 512)          2359808   ['batch_normalization_228[0][0
#                                                                     ]']
#
#  batch_normalization_229 (B  (None, 32, 32, 512)          2048      ['conv2d_234[0][0]']
#  atchNormalization)
#
#  conv2d_235 (Conv2D)         (None, 32, 32, 512)          262656    ['batch_normalization_229[0][0
#                                                                     ]']
#
#  batch_normalization_230 (B  (None, 32, 32, 512)          2048      ['conv2d_235[0][0]']
#  atchNormalization)
#
#  add_76 (Add)                (None, 32, 32, 512)          0         ['batch_normalization_230[0][0
#                                                                     ]',
#                                                                      'batch_normalization_228[0][0
#                                                                     ]']
#
#  activation_76 (Activation)  (None, 32, 32, 512)          0         ['add_76[0][0]']
#
#  conv2d_236 (Conv2D)         (None, 32, 32, 512)          262656    ['activation_76[0][0]']
#
#  batch_normalization_231 (B  (None, 32, 32, 512)          2048      ['conv2d_236[0][0]']
#  atchNormalization)
#
#  conv2d_237 (Conv2D)         (None, 32, 32, 512)          2359808   ['batch_normalization_231[0][0
#                                                                     ]']
#
#  batch_normalization_232 (B  (None, 32, 32, 512)          2048      ['conv2d_237[0][0]']
#  atchNormalization)
#
#  conv2d_238 (Conv2D)         (None, 32, 32, 512)          262656    ['batch_normalization_232[0][0
#                                                                     ]']
#
#  batch_normalization_233 (B  (None, 32, 32, 512)          2048      ['conv2d_238[0][0]']
#  atchNormalization)
#
#  add_77 (Add)                (None, 32, 32, 512)          0         ['batch_normalization_233[0][0
#                                                                     ]',
#                                                                      'batch_normalization_231[0][0
#                                                                     ]']
#
#  activation_77 (Activation)  (None, 32, 32, 512)          0         ['add_77[0][0]']
#
#  conv2d_transpose_15 (Conv2  (None, 64, 64, 256)          524544    ['activation_77[0][0]']
#  DTranspose)
#
#  concatenate_15 (Concatenat  (None, 64, 64, 512)          0         ['conv2d_transpose_15[0][0]',
#  e)                                                                  'activation_75[0][0]']
#
#  conv2d_239 (Conv2D)         (None, 64, 64, 256)          131328    ['concatenate_15[0][0]']
#
#  batch_normalization_234 (B  (None, 64, 64, 256)          1024      ['conv2d_239[0][0]']
#  atchNormalization)
#
#  conv2d_240 (Conv2D)         (None, 64, 64, 256)          590080    ['batch_normalization_234[0][0
#                                                                     ]']
#
#  batch_normalization_235 (B  (None, 64, 64, 256)          1024      ['conv2d_240[0][0]']
#  atchNormalization)
#
#  conv2d_241 (Conv2D)         (None, 64, 64, 256)          65792     ['batch_normalization_235[0][0
#                                                                     ]']
#
#  batch_normalization_236 (B  (None, 64, 64, 256)          1024      ['conv2d_241[0][0]']
#  atchNormalization)
#
#  add_78 (Add)                (None, 64, 64, 256)          0         ['batch_normalization_236[0][0
#                                                                     ]',
#                                                                      'batch_normalization_234[0][0
#                                                                     ]']
#
#  activation_78 (Activation)  (None, 64, 64, 256)          0         ['add_78[0][0]']
#
#  conv2d_242 (Conv2D)         (None, 64, 64, 256)          65792     ['activation_78[0][0]']
#
#  batch_normalization_237 (B  (None, 64, 64, 256)          1024      ['conv2d_242[0][0]']
#  atchNormalization)
#
#  conv2d_243 (Conv2D)         (None, 64, 64, 256)          590080    ['batch_normalization_237[0][0
#                                                                     ]']
#
#  batch_normalization_238 (B  (None, 64, 64, 256)          1024      ['conv2d_243[0][0]']
#  atchNormalization)
#
#  conv2d_244 (Conv2D)         (None, 64, 64, 256)          65792     ['batch_normalization_238[0][0
#                                                                     ]']
#
#  batch_normalization_239 (B  (None, 64, 64, 256)          1024      ['conv2d_244[0][0]']
#  atchNormalization)
#
#  add_79 (Add)                (None, 64, 64, 256)          0         ['batch_normalization_239[0][0
#                                                                     ]',
#                                                                      'batch_normalization_237[0][0
#                                                                     ]']
#
#  activation_79 (Activation)  (None, 64, 64, 256)          0         ['add_79[0][0]']
#
#  conv2d_transpose_16 (Conv2  (None, 128, 128, 128)        131200    ['activation_79[0][0]']
#  DTranspose)
#
#  concatenate_16 (Concatenat  (None, 128, 128, 256)        0         ['conv2d_transpose_16[0][0]',
#  e)                                                                  'activation_73[0][0]']
#
#  conv2d_245 (Conv2D)         (None, 128, 128, 128)        32896     ['concatenate_16[0][0]']
#
#  batch_normalization_240 (B  (None, 128, 128, 128)        512       ['conv2d_245[0][0]']
#  atchNormalization)
#
#  conv2d_246 (Conv2D)         (None, 128, 128, 128)        147584    ['batch_normalization_240[0][0
#                                                                     ]']
#
#  batch_normalization_241 (B  (None, 128, 128, 128)        512       ['conv2d_246[0][0]']
#  atchNormalization)
#
#  conv2d_247 (Conv2D)         (None, 128, 128, 128)        16512     ['batch_normalization_241[0][0
#                                                                     ]']
#
#  batch_normalization_242 (B  (None, 128, 128, 128)        512       ['conv2d_247[0][0]']
#  atchNormalization)
#
#  add_80 (Add)                (None, 128, 128, 128)        0         ['batch_normalization_242[0][0
#                                                                     ]',
#                                                                      'batch_normalization_240[0][0
#                                                                     ]']
#
#  activation_80 (Activation)  (None, 128, 128, 128)        0         ['add_80[0][0]']
#
#  conv2d_248 (Conv2D)         (None, 128, 128, 128)        16512     ['activation_80[0][0]']
#
#  batch_normalization_243 (B  (None, 128, 128, 128)        512       ['conv2d_248[0][0]']
#  atchNormalization)
#
#  conv2d_249 (Conv2D)         (None, 128, 128, 128)        147584    ['batch_normalization_243[0][0
#                                                                     ]']
#
#  batch_normalization_244 (B  (None, 128, 128, 128)        512       ['conv2d_249[0][0]']
#  atchNormalization)
#
#  conv2d_250 (Conv2D)         (None, 128, 128, 128)        16512     ['batch_normalization_244[0][0
#                                                                     ]']
#
#  batch_normalization_245 (B  (None, 128, 128, 128)        512       ['conv2d_250[0][0]']
#  atchNormalization)
#
#  add_81 (Add)                (None, 128, 128, 128)        0         ['batch_normalization_245[0][0
#                                                                     ]',
#                                                                      'batch_normalization_243[0][0
#                                                                     ]']
#
#  activation_81 (Activation)  (None, 128, 128, 128)        0         ['add_81[0][0]']
#
#  conv2d_transpose_17 (Conv2  (None, 256, 256, 64)         32832     ['activation_81[0][0]']
#  DTranspose)
#
#  concatenate_17 (Concatenat  (None, 256, 256, 128)        0         ['conv2d_transpose_17[0][0]',
#  e)                                                                  'activation_71[0][0]']
#
#  conv2d_251 (Conv2D)         (None, 256, 256, 64)         8256      ['concatenate_17[0][0]']
#
#  batch_normalization_246 (B  (None, 256, 256, 64)         256       ['conv2d_251[0][0]']
#  atchNormalization)
#
#  conv2d_252 (Conv2D)         (None, 256, 256, 64)         36928     ['batch_normalization_246[0][0
#                                                                     ]']
#
#  batch_normalization_247 (B  (None, 256, 256, 64)         256       ['conv2d_252[0][0]']
#  atchNormalization)
#
#  conv2d_253 (Conv2D)         (None, 256, 256, 64)         4160      ['batch_normalization_247[0][0
#                                                                     ]']
#
#  batch_normalization_248 (B  (None, 256, 256, 64)         256       ['conv2d_253[0][0]']
#  atchNormalization)
#
#  add_82 (Add)                (None, 256, 256, 64)         0         ['batch_normalization_248[0][0
#                                                                     ]',
#                                                                      'batch_normalization_246[0][0
#                                                                     ]']
#
#  activation_82 (Activation)  (None, 256, 256, 64)         0         ['add_82[0][0]']
#
#  conv2d_254 (Conv2D)         (None, 256, 256, 64)         4160      ['activation_82[0][0]']
#
#  batch_normalization_249 (B  (None, 256, 256, 64)         256       ['conv2d_254[0][0]']
#  atchNormalization)
#
#  conv2d_255 (Conv2D)         (None, 256, 256, 64)         36928     ['batch_normalization_249[0][0
#                                                                     ]']
#
#  batch_normalization_250 (B  (None, 256, 256, 64)         256       ['conv2d_255[0][0]']
#  atchNormalization)
#
#  conv2d_256 (Conv2D)         (None, 256, 256, 64)         4160      ['batch_normalization_250[0][0
#                                                                     ]']
#
#  batch_normalization_251 (B  (None, 256, 256, 64)         256       ['conv2d_256[0][0]']
#  atchNormalization)
#
#  add_83 (Add)                (None, 256, 256, 64)         0         ['batch_normalization_251[0][0
#                                                                     ]',
#                                                                      'batch_normalization_249[0][0
#                                                                     ]']
#
#  activation_83 (Activation)  (None, 256, 256, 64)         0         ['add_83[0][0]']
#
#  conv2d_257 (Conv2D)         (None, 256, 256, 3)          195       ['activation_83[0][0]']
#
# ==================================================================================================
# Total params: 10192963 (38.88 MB)
# Trainable params: 10176067 (38.82 MB)
# Non-trainable params: 16896 (66.00 KB)
# __________________________________________________________________________________________________

# %%
plot_model(model, to_file='model.png', show_shapes=True)

# %% [markdown]
# # Training & Validation

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=10,
    batch_size=64,
    verbose=1,
)
# Out:
# Epoch 1/10
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Model Train Result

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.title("Loss")
plt.plot(train_loss, label="train_loss")
plt.plot(val_loss, label="val_loss")
plt.legend()
plt.show()

# %% [markdown]
# # Evaluation

# %%
y_pred = model.predict(X_test)

randlist = np.random.randint(0, X_test.shape[0], 10)

ax, fig = plt.subplots(10, 3, figsize=(10, 30))
for i, j in zip(range(10), randlist):
    fig[i][0].title.set_text(f"X_test[{j}]")
    fig[i][1].title.set_text(f"y_test[{j}]")
    fig[i][2].title.set_text(f"y_pred[{j}]")
    fig[i][0].imshow(X_test[j])
    fig[i][1].imshow(y_test[j])
    fig[i][2].imshow(y_pred[j])
